# %%
#Задача 1
#Используя цикл for, найдите сумму всех элементов заданного списка. (Без использования встроенных функций sum и т.д.)
my_list = [40, 32, 45, 22, 69, 3, 59, 150, 34, 0, 2, 5, 1, 38, 65, 39, 94]
s = 0
for i in range(len(my_list)):
    s = s + my_list[i]
print("Сумма: ", s)

#Проверка:
print("Проверка: ", sum(my_list))
# Out:
# Сумму по расчету:  698
# Проверка:  698

# %%
#Задача 2
#Напишите функцию, которая принимает на вход список из предыдущего задания и возвращает сумму всех элементов списка. 
#(Без использования встроенных функций sum и т.д.)
def f_sum(l):
    s = 0
    for i in range(len(l)):
        s = s + l[i]
    return s
print("Сумма: ", f_sum(my_list))
l2 = [1,2,5]
print("Сумма: ", f_sum(l2))
# Out:
# Сумма:  698
# Сумма:  8

# %%
#Задача 3
#Используя цикл (любой) найдите значение максимального элемента списка из предыдущего задания.
#(Без использования встроенных функций max и т.д.) Можно использовать встроенные методы списков (любые).
#гуглить нужно фразу "алгоритм поиска максимального элемента массива"
#Пример: для списка [3, 4, 1, 7, 2] значением максимального элемента является число 7
l = my_list.copy()
# = [3, 4, 1, 7, 2]
l_max = l[0]
for i in range(1,len(l)):
    if l_max < l[i]:
        l_max = l[i]
print("макс. для my_list Пузырьком:", l_max)  
print("Проверка:", max(l))
# Out:
# макс. для my_list Пузырьком: 150
# Проверка: 150

# %%
#Задача 4
#Напишите функцию, которая принимает на вход список из предыдущего задания и возвращает его максимальный элемент. 
#(Без использования встроенных функций max и т.д.) Можно использовать встроенные методы списков (любые). 
#Т.е. заверните решение предыдущего задания в функцию.
def f_max(l):
    l_max = l[0]
    for i in range(1,len(l)):
        if l_max < l[i]:
            l_max = l[i]
    return l_max
print("макс. для my_list Пузырьком:", f_max(my_list))  
print("Проверка:", max(my_list))  
print("макс. для [3, 4, 1, 7, 2] Пузырьком:", f_max([3, 4, 1, 7, 2]))  
print("Проверка:", max([3, 4, 1, 7, 2]))
# Out:
# макс. для my_list Пузырьком: 150
# Проверка: 150
# макс. для [3, 4, 1, 7, 2] Пузырьком: 7
# Проверка: 7

# %%
#Задача 5
#Используя список из предыдущего задания (my_list) создайте кортеж и назовите его my_tuple. 
#Найдите индекс элемента, который равен 5. P.S. Используйте один из встроенных методов для кортежей
my_tuple = tuple(my_list)
my_tuple.index(5)
# Out:
# 11

# %%
#Задача 6
#Создайте словарь, соответствующий следующему описанию:
#В честь 8 марта начальник отдела Валера решил принести на работу коробку конфет и угостить коллег :) 
#Красотка Наташа съела две конфеты, ее подруга Алина - целых три, 
#разработчик Марат унес с собой в соседний опен-спейс целых пятнадцать, чтобы поделиться со своей командой, 
#менеджер проекта Лев проходил мимо и съел одну конфету, а 
#сам Валера, будучи сторонником здорового образа жизни, ни съел ни одной.
my_dict = {'Наташа' : 2, 
           'Алина' : 3, 
           'Марат' : 15,
           'Лев' : 1,
           'Валера':0
          }
my_dict
# Out:
# {'Наташа': 2, 'Алина': 3, 'Марат': 15, 'Лев': 1, 'Валера': 0}

# %%
#Задача 7
#Добавьте в словарь из предыдущего задания данные для студента Ромы, 
#который работает неполный рабочий день, и, придя на работу после экзамена, с удовольствием съел 4 конфеты.
#P.S. используйте встроенный метод .update
dict2 = {'Рома': 4}
my_dict.update(dict2)
my_dict
# Out:
# {'Наташа': 2, 'Алина': 3, 'Марат': 15, 'Лев': 1, 'Валера': 0, 'Рома': 4}

# %%
#Задача 8
#Двое друзей решили отправиться в путешествия. Дима посетил следующие страны: Украина, Египет, США, Германия, Дания. 
#Алина же побывала на Украине, в Египте, Испании, Тунисе, Германии, Швейцарии.
#Создайте два множества (set), соответствующие странам, которые посетили Дима и Алина.
#Найдите:
#только те страны, в которых побывали и Дима, и Алина (пересечение)
#все страны, которые посетили друзья (объединение)
#страны, в которых Алина побывала, а Дима еще нет
Dima_set = set(['Украина', 'Египет', 'США', 'Германия', 'Дания'])
Alina_set = set(['Украина', 'Египет', 'Испания', 'Тунис', 'Германия', 'Швейцария'])
i = Dima_set & Alina_set
u = Dima_set.union(Alina_set)
a = Alina_set.difference(Dima_set)
print("пересечение: ",i)
print("объединение: ",u)
print("страны, в которых Алина побывала, а Дима еще нет: ",a)
# Out:
# пересечение:  {'Германия', 'Украина', 'Египет'}
# объединение:  {'Украина', 'Швейцария', 'Германия', 'Египет', 'Испания', 'Дания', 'США', 'Тунис'}
# страны, в которых Алина побывала, а Дима еще нет:  {'Испания', 'Швейцария', 'Тунис'}

# %%
#Задача 9
#Используя циклы, напишите код, который создает список (list) путем конкатенации значений данного листа 
#с целыми числами от 1 до (произвольного) n включительно.
#Пример: для списка ["сосиски", "горчица"] при n = 3 результат должен выглядеть так:
#['сосиски _ 1', 'горчица _ 1', 'сосиски _2 ', 'горчица _ 2', 'сосиски _ 3', 'горчица _ 3']
flowers = ['розы', 'лилии', 'орхидеи', 'пионы']
flowers2 = []
n = int(input("произвольное число: "))
k = 0
for j in range(1,n+1):
    for i in range(len(flowers)):
        flowers2.append(flowers[i] + ' _' + str(j))
        k+=1

print(flowers2)
# Out:
# произвольное число: 5
# ['розы _1', 'лилии _1', 'орхидеи _1', 'пионы _1', 'розы _2', 'лилии _2', 'орхидеи _2', 'пионы _2', 'розы _3', 'лилии _3', 'орхидеи _3', 'пионы _3', 'розы _4', 'лилии _4', 'орхидеи _4', 'пионы _4', 'розы _5', 'лилии _5', 'орхидеи _5', 'пионы _5']
